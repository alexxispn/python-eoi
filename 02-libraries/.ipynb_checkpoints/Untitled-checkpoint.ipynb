# %%
from PIL import Image
from PIL import ImageDraw

image = Image.open("leon.png")
width, height = image.size
canvas = ImageDraw.Draw(image)
for x in range(0, width, 100):
    canvas.line((x, 0, x, height), fill="white", width=12)
for y in range(0, height, 100):
    canvas.line((0, y, width, y), fill="white", width=12)
image.save("leon_grid.png")
Image.open("leon_grid.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x960>

# %%
from PIL import Image, ImageDraw

image = Image.new("RGB", (200, 200), (255, 180, 180))
canvas = ImageDraw.Draw(image)
canvas.chord((10, 10, 190, 190), 0, 360, fill="cyan", width=10)
canvas.chord((10, 10, 190, 190), 0, 90, fill="coral", width=10)
canvas.chord((10, 10, 190, 190), 90, 180, fill="white", width=10)
canvas.chord((10, 10, 190, 190), 180, 270, fill="white", width=10)
image
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
